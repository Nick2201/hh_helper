# %%
import requests      # Для запросов по API
import json          # Для обработки полученных результатов
import time          # Для задержки между запросами
import os            # Для работы с файлами / pathlib
import pandas as pd  # Для формирования датафрейма с результатами

# %%
def getPage(
    page        :int = 0,
    filter_text :str =  'NAME:Аналитик',
    **params_add
    ):
    """
    Создаем метод для получения страницы со списком вакансий.
    Аргументы:
        page - Индекс страницы, начинается с 0. Значение по умолчанию 0, т.е. первая страница
    """
    params = {
        'text': filter_text, # Текст фильтра. В имени должно быть слово "Аналитик"
        'area': 1, # Поиск ощуществляется по вакансиям города Москва
        'page': page, # Индекс страницы поиска на HH
        'per_page': 100, # Кол-во вакансий на 1 странице
    }
    # Справочник для параметров GET-запроса
    params.update(params_add)

    # |between1And3
    req = requests.get('https://api.hh.ru/vacancies', params) # Посылаем запрос к API
    data = req.content.decode() # Декодируем его ответ, чтобы Кириллица отображалась корректно
    req.close()
   
    return data

# %%
additional_params = {
    'type': 'open',
    'experience': 'noExperience',
}

_data = getPage(0, **additional_params)

print(_data)
# Out:
# {"items":[{"id":"83811478","premium":false,"name":"Удалённый аналитик по недвижимости (подработка из дома, от 4 часов, без опыта)","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"Москва","url":"https://api.hh.ru/areas/1"},"salary":{"from":50000,"to":100000,"currency":"RUR","gross":false},"type":{"id":"open","name":"Открытая"},"address":null,"response_url":null,"sort_point_distance":null,"published_at":"2023-07-21T13:28:49+0300","created_at":"2023-07-21T13:28:49+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=83811478","insider_interview":null,"url":"https://api.hh.ru/vacancies/83811478?host=hh.ru","alternate_url":"https://hh.ru/vacancy/83811478","relations":[],"employer":{"id":"5630856","name":"Сакулин Игорь Валерьевич","url":"https://api.hh.ru/employers/5630856","alternate_url":"https://hh.ru/employer/5630856","logo_urls":null,"vacancies_url":"https://api.hh.ru/vacancies?employer_id=5630856","accredited_it_employer":false,"trusted":true},"snippet":{"requirement":"готовность к обучению и усвоению новой информации. - быть на связи и соблюдать сроки. - ответственность, обязательность, внимательность и аккуратность. ","responsibility":"по открытым источникам (Циан, Avito, яндекс.недвижимость и др.) находить объявления по коммерческой недвижимости. - собирать данные по объекту, запрашивать у продавца..."},"contacts":null,"schedule":null,"working_days":[{"id":"only_saturday_and_sunday","name":"Работа только по сб и вс"}],"working_time_intervals":[{"id":"from_four_to_six_hours_in_a_day","name":"Можно работать сменами по 4–6 часов в день"}],"working_time_modes":[{"id":"start_after_sixteen","name":"Можно начинать работать после 16:00"}],"accept_temporary":false,"professional_roles":[{"id":"40","name":"Другое"}],"accept_incomplete_resumes":true,"experience":{"id":"noExperience","name":"Нет опыта"},"employment":{"id":"part","name":"Частичная занятость"},"adv_response_url":null,"is_adv_vacancy":false},{"id":"85016384","premium":false,"name":"Data Analyst","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"Москва","url":"https://api.hh.ru/areas/1"},"salary":{"from":null,"to":3500,"currency":"USD","gross":false},"type":{"id":"open","name":"Открытая"},"address":null,"response_url":null,"sort_point_distance":null,"published_at":"2023-08-14T09:40:37+0300","created_at":"2023-08-14T09:40:37+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=85016384","insider_interview":null,"url":"https://api.hh.ru/vacancies/85016384?host=hh.ru","alternate_url":"https://hh.ru/vacancy/85016384","relations":[],"employer":{"id":"9056230","name":"Offer Now","url":"https://api.hh.ru/employers/9056230","alternate_url":"https://hh.ru/employer/9056230","logo_urls":{"90":"https://hhcdn.ru/employer-logo/5598060.png","240":"https://hhcdn.ru/employer-logo/5598061.png","original":"https://hhcdn.ru/employer-logo-original/994316.png"},"vacancies_url":"https://api.hh.ru/vacancies?employer_id=9056230","accredited_it_employer":false,"trusted":true},"snippet":{"requirement":"Высшее образование. Готовность к релокации. SQL на уровне сложных запросов. Опыт с Power BI / DAX (Как плюс). Уровень Англ от...","responsibility":"Написание технических заданий на разработку витрин данных и дашбордов. Составление диаграмм потоков данных, описание витри. Разработка отчетности в Power BI. "},"contacts":null,"schedule":null,"working_days":[],"working_time_intervals":[],"working_time_modes":[],"accept_temporary":false,"professional_roles":[{"id":"156","name":"BI-аналитик, аналитик данных"}],"accept_incomplete_resumes":false,"experience":{"id":"noExperience","name":"Нет опыта"},"employment":{"id":"full","name":"Полная занятость"},"adv_response_url":null,"is_adv_vacancy":false},{"id":"84983465","premium":false,"name":"Младший аналитик","department":null,"has_test":true,"response_letter_required":false,"area":{"id":"1" ...

# %%
type(_data)
all_ = json.loads(_data)
# all_

# %%
data = [...]  # The list of dictionaries from your JSON

result = []
for item in all_['items']:
    salary = item.get('salary', {})
    
    if salary is None:
        salary_from = 0
        salary_to = 0
        salary_currency = 'RUR'
        salary_gross = False
    else:
        salary_from = salary.get('from', 0)
        salary_to = salary.get('to', 0)
        salary_currency = salary.get('currency', 'RUR')
        salary_gross = salary.get('gross', False)
    
    snippet = item.get('snippet', {})
    requirement = snippet.get('requirement', '')
    responsibility = snippet.get('responsibility', '')

    employer = item.get('employer', {})
    employer_name = employer.get('name', '')

    experience = item.get('experience', {})
    experience_id = experience.get('id', '')
    experience_name = experience.get('name', '')

    area = item.get('area', {})
    area_name = area.get('name', '')

    result.append({
        'id': item.get('id', ''),
        'name': item.get('name', ''),
        'area_name': area_name,
        'salary_from': salary_from,
        'salary_to': salary_to,
        'salary_currency': salary_currency,
        'salary_gross': salary_gross,
        'requirement': requirement,
        'responsibility': responsibility,
        'employer_name': employer_name,
        'experience_id': experience_id,
        'experience_name': experience_name
    })

# %%
result
# Out:
# [{'id': '83811478',
#   'name': 'Удалённый аналитик по недвижимости (подработка из дома, от 4 часов, без опыта)',
#   'area_name': 'Москва',
#   'salary_from': 50000,
#   'salary_to': 100000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'готовность к обучению и усвоению новой информации. - быть на связи и соблюдать сроки. - ответственность, обязательность, внимательность и аккуратность. ',
#   'responsibility': 'по открытым источникам (Циан, Avito, яндекс.недвижимость и др.) находить объявления по коммерческой недвижимости. - собирать данные по объекту, запрашивать у продавца...',
#   'employer_name': 'Сакулин Игорь Валерьевич',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85016384',
#   'name': 'Data Analyst',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 3500,
#   'salary_currency': 'USD',
#   'salary_gross': False,
#   'requirement': 'Высшее образование. Готовность к релокации. SQL на уровне сложных запросов. Опыт с Power BI / DAX (Как плюс). Уровень Англ от...',
#   'responsibility': 'Написание технических заданий на разработку витрин данных и дашбордов. Составление диаграмм потоков данных, описание витри. Разработка отчетности в Power BI. ',
#   'employer_name': 'Offer Now',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84983465',
#   'name': 'Младший аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование. Аналитическое мышление и системность. Отличные навыки работы с MS Excel. Грамотность.',
#   'responsibility': 'Работа аналитиком в проектном офисе программ проектов. Подготовка отчетности по проекту. Формирование аналитических срезов по нагрузке, задачам, бюджету, производительности. ',
#   'employer_name': 'IBS',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85002899',
#   'name': 'Младший аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Обязательные: Высшее ИТ/техническое образование либо последние курсы государственного технического ВУЗа. Технический английский язык. Владение SQL на базовом уровне (навыки...',
#   'responsibility': 'Участие в сборе, анализе, формализации и согласовании требований для построения: ХД и витрин данных на базе ХД. Аналитических систем на...',
#   'employer_name': 'GlowByte',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83749055',
#   'name': 'Младший системный аналитик / стажер',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 75000,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Опыт работы с реляционными СУБД (преимущественно PostgreSQL). Знания SQL запросов на продвинутом уровне. Понимание индексов в PostgreSQL на базовом уровне. ',
#   'responsibility': 'Работа с VK Tax Compliance в части настройки коробочного решения с учетными системами заказчика. Работа с иными решениями налогового мониторинга...',
#   'employer_name': 'САПРАН',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84907338',
#   'name': 'Junior Game Analyst (удаленно)',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Уверенное знание математической статистики и теории вероятностей. Знание игровых продуктовых метрик. Умение работать с большими объёмами данных. Искренний интерес к...',
#   'responsibility': 'Работа с ключевыми продуктовыми метриками (Retention, ARPU, DAU и т.д.). Поиск точек роста проекта с помощью аналитики. ',
#   'employer_name': 'Azur Games',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84774234',
#   'name': 'Системный аналитик (junior / стажер)',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Рассматриваем кандидатов как с опытом работы системным аналитиком, так и без.',
#   'responsibility': 'Финтех - модуль по работе с наличностью (заказ, выдача и внесение наличных). Страхование - разработка Личного кабинета клиента (android). Телеком - личный кабинет...',
#   'employer_name': 'Айтикью Груп',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '79654774',
#   'name': 'Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 65000,
#   'salary_to': 80000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Отсутствие родственников за рубежом. Годность к военной службе по состоянию здоровья. Высшее образование.',
#   'responsibility': 'Обработка информации, подготовка аналитических материалов. Предусмотренные военной службой по контракту.',
#   'employer_name': 'В/ч 2320',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85039219',
#   'name': 'Аналитик данных',
#   'area_name': 'Москва',
#   'salary_from': 60000,
#   'salary_to': 60000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Аналогичный опыт работы приветствуется. Хорошие знания TSQL и Power Query. Аналитические способности, а так же опыт самостоятельного прогаммирования. ',
#   'responsibility': 'Обновление существующих форм отчетности. Анализ, формализация и оптимизация существующих форм отчетности. Написание SQL-запросов различной сложности. Визуальные отчетности Excel через...',
#   'employer_name': 'СИНЕРГИЯ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84940224',
#   'name': 'Стажер-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'В том числе Студент вуза. Техническая специальность в ВУЗе. Знания в области информационных технологий, хотя бы одной из: принципы работы...',
#   'responsibility': 'Исследование области информационных технологий и смежных областей, выявление потенциальных, отличительных технологий для патентования. Проведение анализа текущего уровня техники. ',
#   'employer_name': 'Лаборатория Касперского',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84475333',
#   'name': 'Аналитик продаж на OZON',
#   'area_name': 'Москва',
#   'salary_from': 60000,
#   'salary_to': 80000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Знание основ работы на маркетплейсах. Умеете анализировать информацию и принимать решения на основе сделанных выводов. Ранее работали в области маркетинга...',
#   'responsibility': 'Анализировать, поддерживать и развивать продажи определенных групп товаров, контролировать обязательные показатели ежедневно, удерживать/повышать маржинальность. Отчетность по итогам работы.',
#   'employer_name': 'Мухина Ольга Александровна',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84838942',
#   'name': 'Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 65000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Построение сводных таблиц, умение их анализировать. Навык работы с большим массивом данных из разных источников и умение их консолидировать. ',
#   'responsibility': 'В рабочие задачи будет входить: Строить и улучшать отчеты по бизнес результатам (воронка продаж/ динамика продаж/ контроль нагрузки т.д...',
#   'employer_name': 'ЛОКО-БАНК',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85021439',
#   'name': 'Бизнес - аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Опыт работы бизнес- и/или системным аналитиком в продуктовой команде IT-компании или в консалтинге от 1 года (банки, финтех...',
#   'responsibility': 'Ведение проектов различного уровня сложности. Анализ метрик и принятие решений на основе данных. Сбор, анализ и описание бизнес-требований от...',
#   'employer_name': 'Тинькофф',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85017759',
#   'name': 'Аналитик данных - стажер',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Знания SQL. Желание развиваться в области анализа данных. Аналитический склад ума. Готовность работать с большими массивами данных и формулировать гипотезы...',
#   'responsibility': 'Формировать требования на реализацию проверок качества данных: поиск необходимых данных в ЕХД (Oracle), подготавливать примеры выборки данных (простые SQL-скрипты). ',
#   'employer_name': 'МТС Банк',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84746410',
#   'name': 'Data Analyst',
#   'area_name': 'Москва',
#   'salary_from': 100000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Опыт работы в data analyst - от 2-х лет. Уверенное знание языка Python для анализа данных. Знание SQL и работа...',
#   'responsibility': 'Искать всевозможные взаимосвязи для определения синергии между продуктами. Определять тренды, уметь делать выводы и представлять их в наглядном виде, создавать...',
#   'employer_name': 'Лидстех',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84088306',
#   'name': 'Product Analyst Junior / Продуктовый Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Знание математики и статистики. Знание SQL: до оконных функций. Знание Python. Умение структурировано и обосновано доносить свою точку зрения. ',
#   'responsibility': 'Haraba - российский агрегатор объявлений о продаже автомобилей с пробегом. Хараба не только агрегирует, но и закрывает часть ключевых процессов при...',
#   'employer_name': 'Haraba',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84866376',
#   'name': 'Младший бизнес аналитик',
#   'area_name': 'Москва',
#   'salary_from': 50000,
#   'salary_to': 90000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Проактивность, желание и амбиции развиваться в IT-сфере. Базовый навык переговоров, умение правильно понять бизнес-задачу и корректно сформулировать образ...',
#   'responsibility': 'Базово понимать что такое интернет-маркетинг, B2B-продажи, зачем нужны сервисы рассылки, CRM, IP-телефония, лендинги и т...',
#   'employer_name': 'Интроверт',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84468495',
#   'name': 'Стажер-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Уверенное пользование MS Office (Word, Excel, Power Point). Приветствуется опыт работы с Python (знание библиотеки Pandas и др.). ',
#   'responsibility': 'Помощь в выполнении текущих бизнес-задач в области качества и клиентского опыта по заданиям наставника. Помощь в расчете статистических данных. ',
#   'employer_name': 'МТС',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '80125726',
#   'name': 'Аналитик упоминаний в соцсетях',
#   'area_name': 'Москва',
#   'salary_from': 39000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Грамотно пишете по-русски. Разбираетесь в работе социальных сетей. Работали с MS Excel и PowerPoint. Умеете обрабатывать большие объёмы данных. ',
#   'responsibility': 'Работать с системами мониторинга упоминаний в соцсетях и СМИ. Писать поисковые запросы и фильтровать упоминания по различным критериям в зависимости...',
#   'employer_name': 'Яндекс Крауд',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84685839',
#   'name': 'Аналитик данных',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Отличное знание Excel (Сводные таблицы, Power Query/PowerPivot). Знание SQL и опыт работы с MS SQL, знание Phyton будет плюсом. ',
#   'responsibility': 'Сбор, анализ и документирование взаимодействия систем учета в рамках основных метрик. Поддержание документации в актуальном состоянии. Сверка и сопоставления данных...',
#   'employer_name': 'СберМегаМаркет',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83185391',
#   'name': 'Junior Аналитик',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 120000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Интерес к теме. Внимательность, любопытство. Коммерческий опыт работы аналитиком не требуется.',
#   'responsibility': 'Аналитик будет разбираться в доменной области с помощью DS-навыков. Работа может включать анализ требований к компании со стороны торговых...',
#   'employer_name': 'Доценко Дарья',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83619428',
#   'name': 'Аналитик-стажер',
#   'area_name': 'Москва',
#   'salary_from': 60000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Желательно знание английского языка. Владение Excel или Google Таблицы на уровне базовый. Аналитический склад ума. Исполнительность.',
#   'responsibility': 'Поиск и анализ информации. Анализ первичной документации (отчетности компаний). Мониторинг основных источников новостей.',
#   'employer_name': 'Актив Групп',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83376955',
#   'name': 'Младший бизнес-аналитик',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 70000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Неоконченное высшее или высшее техническое/экономическое образование. Уверенный уровень владения MS Office и Google Docs. Сильные аналитические способности, умение вникать...',
#   'responsibility': 'Проведение аналитических работ в рамках реализации проектов: Подготовка отчетных материалов, презентаций, коммерческих предложений и т.п.',
#   'employer_name': 'Intelligent Analytics',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84210020',
#   'name': 'Младший аналитик данных',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Без соответствующего опыта в области BI. Выпускников ВУЗов (законченный уровень «бакалавр»; естественно-научный, технический, экономический профили). Уверенно владеете программой MS...',
#   'responsibility': 'Обрабатывать данные из реляционных СУБД с помощью языка SQL. Заниматься задачами ETL. Вести прикладные расчеты «по требованию» в среде MS...',
#   'employer_name': 'Ростелеком - Центры обработки данных',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84570015',
#   'name': 'Junior data analyst',
#   'area_name': 'Москва',
#   'salary_from': 70000,
#   'salary_to': 90000,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Высокие навыки работы с MS Office (особенно Excel и PowerPoint). Умение работать с BI-системами и БД будет плюсом. ',
#   'responsibility': 'Разработка информационно-аналитических материалов на основе больших данных информационных систем министерства и внешних источников. Контроль ведения справочников НСИ, ETL-задач. ',
#   'employer_name': 'Кадровое агентство АНО РСВ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84737571',
#   'name': 'Младший аналитик (стажер)',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Значительно усилит навыки MS Excel, Tableau. Опыт работы или любое образование в области, предусматривающей работу с цифрами, анализом, обработкой большого...',
#   'responsibility': 'Через несколько недель интенсивного обучения стажер будет обновлять уже настроенные отчёты и выгружать простые данные без обработки, делать простые отчёты...',
#   'employer_name': 'OSTIN',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84190434',
#   'name': 'Бизнес-аналитик (стажёр)',
#   'area_name': 'Москва',
#   'salary_from': 100000,
#   'salary_to': 160000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Опыт работы в разработке необязателен. Приветствуются базовые знания SQL.',
#   'responsibility': 'Сбор требований. Написание технических заданий. Анализ бизнес-процессов. Составление схем процессов в нотациях BPMN и UML. Постановка задач разработчикам. ',
#   'employer_name': 'SilVal',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83756975',
#   'name': 'Младший аналитик (IT)',
#   'area_name': 'Москва',
#   'salary_from': 100000,
#   'salary_to': 140000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Опыт работы в данной сфере необязателен. Перед трудоустройством проводится подготовка. Приветствуются базовые знания SQL, Java, Python, C#, JavaScript, PHP.',
#   'responsibility': 'Анализ процессов компании. Составление схем бизнес-процессов. Составление технических заданий (ТЗ). Постановка задач разработчикам. Контроль сроков выполнения задач. ',
#   'employer_name': 'Olima',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83274303',
#   'name': 'Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование (либо студент последних курсов). Уверенный пользователь Excel (сложные формулы, сводные таблицы) и Power Point. Опыт работы с большими...',
#   'responsibility': 'Анализ ресурсов логистической системы по отношению к объемам планируемого и имеющегося товарного потока, товарного запаса, а также по отношению к...',
#   'employer_name': 'Винлаб',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '81822043',
#   'name': 'Младший бизнес-аналитик / Специалист по описанию бизнес-процессов',
#   'area_name': 'Москва',
#   'salary_from': 40000,
#   'salary_to': 60000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Опыт моделирования и описания бизнес-процессов. Опыт формирования бизнес-требований и технических заданий.',
#   'responsibility': 'Много и эффективно работать головой, думать, созидать, творить. Собирать, верифицировать, анализировать и описывать процессы и инструкции для сотрудников компании. ',
#   'employer_name': 'OASIS, группа компаний',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84853040',
#   'name': 'Системный аналитик Junior',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Знание основ объектно-ориентированного программирования. Желательно знание: SQL, UML, BPMN или иных нотаций. Грамотная письменная и устная речь.',
#   'responsibility': 'Взаимодействие с заказчиком. Сбор требований. Выработка предложений для реализации требований заказчика. Анализ нормативной документации. Разработка технического задания, сдача работ. ',
#   'employer_name': 'Ред Софт',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85065691',
#   'name': 'Аналитик данных',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование. Релевантный опыт работы от 1 года. Продвинутый уровень MS Office. Знание SQL. Знание ПК (Excel продвинутый уровень, Power...',
#   'responsibility': 'Работа с SQL Server Management Studio. Написание запросов (сложные, оконные функции) для выгрузки больших массивов данных. Редактирование существующих таблиц (добавление...',
#   'employer_name': 'ВТБ Лизинг',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84965857',
#   'name': 'Менеджер по маркетплейсам (продажа, реклама, аналитика, удаленно)',
#   'area_name': 'Москва',
#   'salary_from': 40000,
#   'salary_to': 50000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Ну и хорошо бы уметь строить стратегию продвижения товара.',
#   'responsibility': 'Ведение личного кабинета. Настройка и контроль внутренней рекламы,- конечно важно)). Составление оформление отгрузок, контроль остатков. Взимодействие с фулфилментом. ',
#   'employer_name': 'Сальников Михаил Валерьевич',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84433053',
#   'name': 'Стажер продуктовый аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Ты — студент или выпускник профильного направления. Знаешь Excel на продвинутом уровне, умеешь работать с формулами и сводными таблицами. ',
#   'responsibility': 'Анализировать данные, строить и проверять гипотезы для улучшения продуктовых метрик вместе с продакт-менеджерами. Искать точки роста, определять причины изменений...',
#   'employer_name': 'МТС',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84813446',
#   'name': 'Аналитик по экономической безопасности',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее финансовое/экономическое образование/юридическое. Опыт работы с большим объемом данных. Понимание учредительных документов согласно законодательству РФ. Понимание принципов работы...',
#   'responsibility': 'Верификация данных юридических и физических лиц. - Поиск и сбор информации в отношении контрагентов. - Работа с программами СПАРК, СЕЛДОН и т...',
#   'employer_name': 'TKM',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85046099',
#   'name': 'Младший бизнес-аналитик Track&Trace',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'У тебя высшее (техническое) образование или ты - студент последних курсов. Владеешь английским на уровне не ниже intermediate. Умеешь внимательно слушать...',
#   'responsibility': 'Участие в проектах внедрения системы маркировки и отслеживания движения товаров в роли консультанта в крупных международных компаниях: Сбор и фиксация...',
#   'employer_name': 'Navicon',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84691603',
#   'name': 'Стажер-аналитик (SQL)',
#   'area_name': 'Москва',
#   'salary_from': 45000,
#   'salary_to': 55000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Рассматриваем образование от неоконченного высшего (информатика, математика, техника, инженерия, робототехника, инфобезопасность) последние курсы ВУЗов, но с возможностью работы в офисе...',
#   'responsibility': 'Пройти обучение на исп. сроке. Основные задачи в анализе данных, работа в Excel (ВПР, сводные таблицы). Работа в 1С...',
#   'employer_name': 'Компания ПЭК',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84058162',
#   'name': 'Младший аналитик / Ассистент департамента',
#   'area_name': 'Москва',
#   'salary_from': 77000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование (преимущество). Высокая грамотность письменной речи. Опытный пользователь Excel. Опыт работы не обязателен. Желание и готовность обучаться.',
#   'responsibility': 'Ведение УКЭП и МЧД. Отчетность для внутренних заказчиков. Маршрутизация запросов от внутренних заказчиков. Подготовка исходных данных для аналитики Медицинского департамента. ',
#   'employer_name': 'MedPoint24',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83781433',
#   'name': 'Ассистент аналитика / инженера данных',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 40000,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Знаете SQL. Внимательны в деталям. Знаете английский на уровне чтения документации. Не стесняетесь задать вопрос, если что-то не понимаете.',
#   'responsibility': 'Писать SQL-запросы. Настраивать пайплайны сбора и обработки данных. Визуализировать данные. Взаимодействовать с заказчиками по результатам проделанной работы.',
#   'employer_name': 'Адвентум',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84438265',
#   'name': 'Системный аналитик CRM/BPM (стажер)',
#   'area_name': 'Москва',
#   'salary_from': 40000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование по профилю (можно последний год обучения), с возможностью уделять работе 35-42 часов в рабочую неделю. ',
#   'responsibility': 'Активно общаться с заказчиком и с коллегами на всех этапах проекта. Придумываться, проектировать и описывать бизнес-процессы, прототипы ИТ-решений...',
#   'employer_name': 'Nobilis.Team',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84839749',
#   'name': 'Начинающий аналитик',
#   'area_name': 'Москва',
#   'salary_from': 45000,
#   'salary_to': 45000,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Умение анализировать данные. Умение анализировать нормативно-правовые документы, методологические рекомендации, связанные реализуемой функциональностью. Навыки сбора и анализа требований в рамках...',
#   'responsibility': 'Обеспечение сбора и организация процесса загрузки данных в аналитические системы, включая получение структурированных и не структурированных данных из различных источников...',
#   'employer_name': 'Межрегиональное Управление Федерального Казначейства по Централизованной Обработке Данных',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84425640',
#   'name': 'Стажер-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Выпускник или учащийся (МГУ, ВШЭ, Физтех, Бауманка, МАИ). Имеешь сильные математические способности и аналитическое мышление. У тебя есть желание развиваться...',
#   'responsibility': 'Обслуживание автопарка. Работа с грузами и логистика. Организации поездок и мероприятий. Освоить текущую структуру данных компании и уметь в ней...',
#   'employer_name': 'Передовые Платежные Решения',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84826896',
#   'name': 'Стажер Бизнес-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Наполнять и поддерживать в актуальном состоянии базы знаний. ТЫ НАМ ПОДХОДИШЬ, ЕСЛИ: Ты — студент или выпускник профильного направления.',
#   'responsibility': 'RIM (Remote Identification Module) – единое решение по удаленному сбору данных физического лица в digital-канале и их подтверждения через гос.источники. ',
#   'employer_name': 'МТС',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84836684',
#   'name': 'Младший системный аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Готовы взять в команду как опытных, так и начинающих специалистов. Высшее образование в области информационных технологий, математики или физики, технических...',
#   'responsibility': 'Участие в качестве младшего системного аналитика в проектах комплексной цифровизации HR-процессов в крупных компаниях. Обследование процессов заказчиков, сбор требований...',
#   'employer_name': 'Мираполис',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85013809',
#   'name': 'Младший аналитик по бизнес-планированию и моделированию (SQL, VBA)',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование по специальности финансы/экономика/математика. Уверенное знание Excel, VBA. Знание SQL (минимально - опыт написания простых запросов).',
#   'responsibility': 'Участвовать в оценке маржинальности продуктов розничного бизнеса. Участвовать в работе с продуктовыми калькуляторами. Участвовать в разработке, развитии и оптимизации расчетных...',
#   'employer_name': 'БАНК УРАЛСИБ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84748859',
#   'name': 'Аналитик данных',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 80000,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Умение работать в многозадачном режиме. MS Excel уверенный пользователь (power query, power pivot, dax). PostgreSQL уверенный пользователь. Python (обработка данных...',
#   'responsibility': 'Тепличные комплексы общей площадью 304,3 га в Ставропольском крае. Липецкой, Тульской, Воронежской и Ленинградской областях. Цехи по фасовке овощей. ',
#   'employer_name': 'АПХ ЭКО-культура',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83775277',
#   'name': 'Ассистент маркетолога-аналитика / оператор баз данных',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Приобрести практический опыт рыночного анализа. Получить знания в реализации исследовательских проектов. Узнать «изнанку» исследовательского бизнеса. Расширить свой кругозор в проектах...',
#   'responsibility': 'Собирать и структурировать данные из открытых источниках в Интернете. Работать с большими таблицами в Excel, подготавливать их для последующей обработки. ',
#   'employer_name': 'Маркетинговая группа VIGOR Consult',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84294782',
#   'name': 'Data analyst / Data Scientist',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее/неполное высшее образование (техническое/финансовое/экономическое). Навыки анализа данных для решения практических задач. Опыт написания SQL запросов. ',
#   'responsibility': 'Выгрузка данных из корпоративного хранилища данных. Проведение анализа для проверки гипотез совместно с бизнес-подразделениями. Построение аналитических представлений и отчетов...',
#   'employer_name': 'РОСБАНК',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83403891',
#   'name': 'Аналитик-стажер',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 30000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Внимательность к деталям. — Самостоятельность. — Желание учиться. — Готовность брать на себя ответственность за результат.',
#   'responsibility': 'Проведение исследований - оцифровка бизнес процессов в магазинах Вкусвилла. Два или три дня в неделю ( с 7:45 и до 22...',
#   'employer_name': 'ВкусВилл',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83960866',
#   'name': 'Стажер-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Энергичного и амбициозного студента, желающего делать классные проекты вместе с молодой командой. Готового к большому объёму задач, многозадачности. ',
#   'responsibility': 'Работать с цифрами и аналитикой в компании c целью оптимизации. Находить ответы для новых задач и вопросов в бизнесе. ',
#   'employer_name': 'ПАПА ДЖОНС',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84295315',
#   'name': 'Младший аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование или проходишь последние курсы обучения (предпочтительно: математика, статистика, информатика). Готовность работать полный день в офисе 5/2 (для...',
#   'responsibility': 'Разработка веб-форм для онлайн-опросов в нашем ПО с использованием скриптов. Работа с базами данных, полученных в ходе опросов...',
#   'employer_name': 'Magram MR',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83940096',
#   'name': 'Младший аналитик (Researcher), Executive Search',
#   'area_name': 'Москва',
#   'salary_from': 70000,
#   'salary_to': 100000,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Уверенное владение русским и английским языками (письменное и устное). Навыки поиска информации в онлайн ресурсах. Креативное мышление, и умение находить...',
#   'responsibility': 'Подготовка информации о компаниях и рынках для формирования стратегии поиска кандидатов на руководящие позиции. Формирование списка целевых компаний в соответствии...',
#   'employer_name': 'RosExpert',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84103079',
#   'name': 'Бизнес-аналитик junior',
#   'area_name': 'Москва',
#   'salary_from': 60000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Если ВЫ обладаете желанием развиваться в IT сфере на должности бизнес-аналитика, строить свою карьеру в компании - производителе самоклеящихся материалов...',
#   'responsibility': 'Изучать 1С ЕРП и CRM системы. Общаться с пользователями, выявлять основные функциональные и бизнес требования. Участвовать в разработке и...',
#   'employer_name': 'Босла',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83617095',
#   'name': 'Финансовый аналитик',
#   'area_name': 'Москва',
#   'salary_from': 100000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Высшее образование или последний курс университета (желательно экономическое / математическое). Желательно знание английского языка. Владение Excel и Google Таблицы на уровне...',
#   'responsibility': 'Поиск и анализ информации. Подготовка письменных аналитических материалов и презентаций по анализируемым компаниям. Анализ первичной документации (отчетности компаний). ',
#   'employer_name': 'Актив Групп',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84350594',
#   'name': 'Редактор-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 50000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': None,
#   'responsibility': 'Писать материалы в раздел: обзоры рынков, интервью, истории технологических компаний и подборки стартапов. Работать с картами и рейтингами. ',
#   'employer_name': 'РБ.РУ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84935232',
#   'name': 'Стажер-аналитик Data Governance',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Желательно умение читать/разбирать процедуры. - Общее понимание принципов построения витрин данных.',
#   'responsibility': 'Проведение интервью с представителями бизнес-заказчиков. - Анализ и структурирование требований бизнеса. - Разработка шаблонов описания данных и их наполнение в рамках...',
#   'employer_name': 'Московская Биржа',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85039066',
#   'name': 'Аналитик по управленческой отчетности',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Имеет высшее техническое/экономическое образование. Имеет опыт работы в Банке ТОП-30 в роли аналитика (построение управленческой отчетности). ',
#   'responsibility': 'Основные функции: Построение управленческой отчетности по продуктам Банка. Взаимодействие со смежными подразделениями в части определения доходов и расходов подразделения. ',
#   'employer_name': 'Газпромбанк',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84460892',
#   'name': 'Аналитик-стажер',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Аналитический склад ума, умение проводить исследования и анализировать информацию из открытых источников (отчеты компаний, пресс-релизы, новостные статьи, отчеты аналитиков...',
#   'responsibility': 'Анализ рынка и систематический исследовательский анализ, включая сбор и анализ данных, выявление трендов, проведение SWOT-анализа и др. методов анализа. ',
#   'employer_name': 'ЦИФРА',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83783593',
#   'name': 'Системный аналитик (Удаленно)',
#   'area_name': 'Москва',
#   'salary_from': 50000,
#   'salary_to': 70000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Умение быстро находить и структурировать нужную информацию. Умение работать в сжатые сроки, соблюдение договорённостей. Грамотность. Системность. Заинтересованность в работе. ',
#   'responsibility': 'В поиске системного сотрудника, умеющего держать все задачи под контролем, грамотно их распределяя, а так же своевременно контролировать все рабочие...',
#   'employer_name': 'Премиум Импорт',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85062122',
#   'name': 'Стажер в Центр риск-отчетности и аналитики',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Быть выпускником или студентом последних курсов (4 курс бакалавриата, 1-2 курс магистратуры). Умение работать с данными. Знание SQL (практический...',
#   'responsibility': 'Автоматизировать и развивать риск-отчетность: создание и доработка алгоритмов её формирования, написание бизнес-требований на автоматизацию отчетности. Осуществлять мониторинг и...',
#   'employer_name': 'Банк Открытие',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84915396',
#   'name': 'Системный аналитик (junior)',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Умение быстро разбираться в новых областях. Знание нотации UML, понимание протоколов веб-сервисов, форматов обмена данными (xml, json и др.). ',
#   'responsibility': 'Выполнение задач, связанных с подключением потребителей к сервисам Системы. Проработка интеграции, разработка спецификации требований, кастомизация решения. Задачи: Проработка интеграционных требований. ',
#   'employer_name': 'СБЕР',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84853873',
#   'name': 'Стажер-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'MS Office, в т.ч. Excel обязательно, желательно VBA.',
#   'responsibility': 'Подготовка статистических данных для Руководства подразделения.',
#   'employer_name': 'РОСБАНК',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84427074',
#   'name': 'Junior Analyst',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Desire to develop in Retail. Focus on details and passion for numbers. Customer-oriented approach. Final year student / High Degree...',
#   'responsibility': 'Managing retail reports: support regular reports and providing reports on request. Support of Retail team and stores with documents flow. ',
#   'employer_name': 'AMAZING RED',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84856245',
#   'name': 'Marketing Intern / Стажер-аналитик в команде маркетинга',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Ты в том числе студент ВУЗа. Тебе интересно развиваться в маркетинге и стремишься получить маркетинговое образование. У тебя аналитическое мышление...',
#   'responsibility': 'Анализ данных по запускам продуктов, составление рекомендаций и визуализация полученных данных. Изучение рынка и анализ конкурентов. Операционная поддержка команды, работа...',
#   'employer_name': 'Unilever',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '81936905',
#   'name': 'Экономический аналитик',
#   'area_name': 'Москва',
#   'salary_from': 100000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Вы - выпускник ВУЗа (экономика/финансы/банковское дело). Способны обрабатывать и анализировать в ручном режиме большие объемы разноплановой информации (не Big...',
#   'responsibility': 'Осуществлять ручной сбор текстовой и числовой информации в интернете и во внутренних источниках. Обрабатывать и систематизировать информацию. Составлять аналитические заключения.',
#   'employer_name': 'Авангард, АКБ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '81602134',
#   'name': 'Аналитик (начинающий специалист)',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Имеешь законченное высшее образование или в процессе сдачи гос. экзаменов и получения диплома. Имеешь аналитический склад ума и готов его...',
#   'responsibility': 'Диагностика бизнес-процессов клиентов и формирование инициатив по их совершенствованию. Анализ рынка и поиск возможностей развития. Разработка презентационных материалов. ',
#   'employer_name': 'Рексофт',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84564627',
#   'name': 'Аналитик-букмекер (игровая безопасность)',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Интересуешься событиями спорта или одного из них (футбол, хоккей, теннис и т.д.). Хорошо знаешь правила основных видов спорта (футбол...',
#   'responsibility': 'Анализ игроков и ставок. Сбор и обработка большого количества информации. Работать со специальным программным обеспечением.',
#   'employer_name': 'АйтиМедиаСервис',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84692739',
#   'name': 'Стажер-аналитик в команду развития и сопровождения процессов работы с данными',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Уверенное знание SQL. Навыки системного мышления. Развитые навыки коммуникации. Знание английского языка на уровне чтения технической документации. Опыт работы в...',
#   'responsibility': 'Анализировать данные и разбираться в требованиях бизнеса к качеству этих данных для дальнейшей поддержки и разработки проверок качества данных. ',
#   'employer_name': 'Райффайзен Банк',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84918132',
#   'name': 'Data аналитик / Стажер',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Аналитический склад ума, системное мышление, умение быстро вникать в суть проблемы, широкий кругозор, быстрая обучаемость. Базовые знания SQL. ',
#   'responsibility': 'Анализировать различные источники данных с целью выявления новых возможностей для развития продукта. Выполнять операционную работу по улучшению продукта. ',
#   'employer_name': 'Леруа Мерлен',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '81293483',
#   'name': 'Аналитик-стажер',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Общая осведомленность о разработке ПО. Понимание SDLC. Знание основных принципов Agile-разработки. Знание классификации требований по BABOK. Понимание основных этапов...',
#   'responsibility': 'Участвовать в сборе и проработке требований к системе. Актуализировать проектную документацию. Собирать и систематизировать обратную связь по продукту.',
#   'employer_name': 'Т1 Консалтинг',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84650382',
#   'name': 'Младший системный аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Профильное образование. Понимание основ проектирования реляционных БД. Знание SQL. Грамотный русский язык, умение ясно излагать свои мысли. Пунктуальность, ответственность и...',
#   'responsibility': 'Проверка контрагентов: экспресс-оценка рисков и благонадежности компании, оценка масштабов бизнеса и кредитоспособности. Выявление аффилированности, поиск бенефициаров, анализ коррупционных рисков. ',
#   'employer_name': 'Интерфакс',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84354142',
#   'name': 'Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Профессиональные навыки Excel, навыки написания скриптов и макросов, умение работать с БД 1С. Высокий уровень коммуникабельности, умение легко общаться...',
#   'responsibility': 'Отрисовка и выстраивание полноценного процесса по учету доменов. Ведение реестра по доменам. Отражение необходимой информации в личном кабинете провайдера. ',
#   'employer_name': 'Спортмастер',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84903629',
#   'name': 'Business Analyst (Trainee)/Бизнес-аналитик (стажер) в отдел цифровой трансформации',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Учащийся бакалавриата/магистратуры в области анализа и проектирования бизнес- процессов, либо схожих дисциплинах. Готовность уделять стажировке от 16 часов в...',
#   'responsibility': 'Изучение бизнес-процессов компании, описание бизнес-процессов для их последующей адаптации в рамках проектов трансформации, участие в описании и проектировании...',
#   'employer_name': 'Air Liquide',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85021459',
#   'name': 'Бизнес-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Техническую грамотность - понимание, что такое Open API, Rest, Soap и др. Хорошие знания в computer science - что такое информационные системы...',
#   'responsibility': 'Прорабатывать сценарии взаимодействия сервисов при реализации бизнес-функциональности. Проработка и анализ клиентского пути, проверка в рамках UX дизайна, а также...',
#   'employer_name': 'idaproject',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84415848',
#   'name': 'Стажер - аналитик продукта',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Выпускник (предпочтительно со специализацией в области финансов, экономики, менеджмента, информационных технологий). Опытный пользователь MS Office. Развитые аналитические способности и системное...',
#   'responsibility': 'Сбор, обработка и анализ данных для улучшению продукта. Подготовка функциональных требований к IT-решениям. Подготовка презентаций. И выполнение других задач...',
#   'employer_name': 'ONE STORY',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '85044053',
#   'name': 'Младший аналитик',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 50000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Уверенное владение MS Excel на уровне сводных таблиц и функции "ВПР". Внимание к деталям, аккуратность, коммуникабельность, аналитический склад ума.',
#   'responsibility': 'Анализ продаж по категории, оборачиваемости. Составление краткосрочного прогноза на основе статистики продаж. Решение оперативных вопросов по категории. Ведение отчетности.',
#   'employer_name': 'Мираторг, Агропромышленный холдинг',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84487324',
#   'name': 'Junior Market Researcher & Analyst (Remote)',
#   'area_name': 'Москва',
#   'salary_from': 45000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Proficiency in MS Office. - Strong analytical and research skills. - Attention to detail to ensure accurate data capture. - Excellent computer skills...',
#   'responsibility': 'Opportunities for professional growth and advancement based on performance and contribution.',
#   'employer_name': 'Бизапс',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84056342',
#   'name': 'Стажер-аналитик ИТ процессов',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование. Понимание ключевых концепций процессного управления ITSM. Умение систематизировать информацию. Умение разрабатывать нормативные и методические документы. Навыки самообучения и...',
#   'responsibility': 'Анализ ИТ процессов на полноту и корректность. Взаимодействие с коллегами из ИТ и бизнеса для поиска проблемных мест. ',
#   'employer_name': 'Райффайзен Банк',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84411139',
#   'name': 'Аналитик программ лояльности/менеджер программ лояльности',
#   'area_name': 'Москва',
#   'salary_from': 170000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Высшее техническое образование или высшее образование в области маркетинга. Опыт анализа маркетинговых активностей, проведения a/b тестов. Знание основ факторного...',
#   'responsibility': 'Сегментация клиентов по RFM, изучение поведения пользователей, шаблонов потребления. Отслеживание динамики сегментов, предоставление информации в динамике по переходам клиентов из...',
#   'employer_name': 'Ароматный мир',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '76506470',
#   'name': 'Аналитик БД',
#   'area_name': 'Москва',
#   'salary_from': 60000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Написание запросов SQL (Postgres, знание T-sql будет плюсом). Требования: Высшее образование (техническое как преимущество). Понимание принципов построения реляционных БД. ',
#   'responsibility': 'Разрабатывать BI функциональность для анализа и изменения данных. Улучшать процессы и составлять необходимую документацию по BI решениям.',
#   'employer_name': 'ГБУ МО МОМИАЦ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84446283',
#   'name': 'Продуктовый аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Критическое мышление. Умение аргументированно отстаивать свою точку зрения. Опыт работы хотя бы с одним из языков программирования (базовые алгоритмы) или...',
#   'responsibility': 'Выделять ключевые метрики и проводить предварительный анализ различных инициатив. Выдвигать и проверять эффективность различных гипотез по развитию проектов. ',
#   'employer_name': 'Тинькофф',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84160851',
#   'name': 'Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование. Знание инструментов визуализации (Tableau , PowerBI) (желательно). Умение видеть за цифрами причины и суть явлений и выделять главное. ',
#   'responsibility': 'Формирование выгрузок из корпоративных систем. Анализ и обработка данных. Предиктивный (прогнозный) анализ. Взаимодействие с администраторами БД по вопросам качества данных. ',
#   'employer_name': 'СИСТЭМ ЭЛЕКТРИК',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84887924',
#   'name': 'Стажер-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Готовность работать 5/2 очно, полный день (8 часов), от 6 месяцев. Выпускники или в том числе студенты старших курсов...',
#   'responsibility': 'Участие в проектной деятельности в роли ассистента эксперта или архитектора. Деловая переписка. Предварительный анализ и оценка технических документов на различных...',
#   'employer_name': 'ФКУ ГОСУДАРСТВЕННЫЕ ТЕХНОЛОГИИ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83775605',
#   'name': 'Аналитик (маркетплейс)',
#   'area_name': 'Москва',
#   'salary_from': 55000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Имеет минимальный опыт аналитиком или образование. Знает XL на среднем уровне. Умеет выражать свои мысли словами и буквами через клавиатуру. ',
#   'responsibility': 'Работа в аналитической программе mpstats (в течение практически всего дня). Поиск товара, анализ отзывов на товары. Ведение таблиц. ',
#   'employer_name': 'РИГ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83924056',
#   'name': 'Экономист-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 95000,
#   'salary_to': 110000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Приветствуется опыт в теплоснабжения и (или) в электроснабжения. Владения Excel. Аналитическое, системное мышление. Свободное владение прочими программами MS Office.',
#   'responsibility': 'Ценообразование на товары (услуги) в сфере тепло- и (или) электроснабжения. Расчет финансово-экономических показателей тепло- и (или) электроэнергетических компаний. ',
#   'employer_name': 'КонсалтПро',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '80901267',
#   'name': 'Младший аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее профессиональное образование (техническое, экономическое). Отличная письменная и устная речь. Уверенное знание Microsoft Office. Уверенное знание статистики и математических методов...',
#   'responsibility': 'Проверка расчетных статистических показателей. Эконометрическая проверка гипотез относительно тематики исследования. Интерпретация и визуализация данных по итогам исследований. Контроль показателей, выводимых...',
#   'employer_name': 'Правительство Москвы',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84573878',
#   'name': 'Младший финансовый аналитик',
#   'area_name': 'Москва',
#   'salary_from': 70000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Знание excel / google tables. Аналитический склад ума. Ответственный подход к работе.',
#   'responsibility': 'Сверка данных по расходам и доходам. Ведение внутренней отчетности. Помощь ведущему финансовому аналитику.',
#   'employer_name': 'ГРИН РЕЙ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84513469',
#   'name': 'Аналитик (рестораны)',
#   'area_name': 'Москва',
#   'salary_from': 58000,
#   'salary_to': 65000,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': None,
#   'responsibility': '1. Ежедневное введение основных чек-листов ресторанов (Хоспер, Открытие/Закрытие смены Менеджера, Открытие/Закрытие смены Бармена, Открытие/Закрытие смены Хостес). ',
#   'employer_name': 'Рублёвский',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84948575',
#   'name': 'Стажер-аналитик бизнес-процессов',
#   'area_name': 'Москва',
#   'salary_from': None,
#   'salary_to': 40000,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Tы — студент или выпускник профильного направления (бизнес-информатика, менеджмент, экономика, социология, маркетинг). Владеешь Excel на продвинутом уровне. Умеешь или хочешь...',
#   'responsibility': 'Проводить анализ эффективности системы обучения и развития. Выявлять узкие места, неактуальности. Проводить анализ и описывать действующие процессы AS-IS. ',
#   'employer_name': 'МТС',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84484191',
#   'name': 'Младший кредитный аналитик',
#   'area_name': 'Москва',
#   'salary_from': 80000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': True,
#   'requirement': 'Оконченное высшее образование. Знания основ финансового анализа деятельности предприятий. Базовые знания бухгалтерского учета. Выполнение задач в установленные сроки. ',
#   'responsibility': 'Работа с корпоративными клиентами Банка. Финансовый анализ юридических лиц.',
#   'employer_name': 'Совкомбанк',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84511523',
#   'name': 'Стажер-аналитик банковского сектора',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высокий уровень владения Excel (ВПР, макросы, сводные таблицы). Хорошее владение Power Point (понимание визуализации данных). Опыт работы с текстовой/речевой...',
#   'responsibility': 'Проведение интервью и сбор необходимой информации. Агрегирование и анализ собранной информации. Формирование отчетности. Подготовка презентаций в PowerPoint. Работа в программе...',
#   'employer_name': 'Axenix (ранее Accenture)',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '82777498',
#   'name': 'Бизнес-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Умение работать с большими объемами данных. Хорошие аналитические способности, умение докапываться до сути проблем. Работоспособность, целеустремленность, умение доводить дело до...',
#   'responsibility': 'Много и эффективно работать головой, думать, креативить, созидать, творить. Штурмовать проблемы, выдвигать идеи. Воплощать идеи в жизнь, ставить ТЗ для...',
#   'employer_name': 'Тинькофф',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '83301272',
#   'name': 'Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Инициативность, желание развиваться самому и развивать продукты страхования. Знание основ теории вероятности, математической статистики. Опыт применения математических моделей на практике. ',
#   'responsibility': 'Анализ результатов деятельности компании по продажам и убыткам, формирование предложений по улучшению результатов. Подготовка аналитических отчетов по курируемым видам страхования...',
#   'employer_name': 'СОГАЗ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84694141',
#   'name': 'Стажер-аналитик по информационной безопасности',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Образование в сфере информационной безопасности (от 3-4 курса обучения). Знание законодательства РФ и требований регуляторов в области ИБ (федеральные...',
#   'responsibility': 'Участие в разработке и согласовании нормативных документов в области ИБ (политики, регламенты, инструкции и др.). Участие в обследовании процессов обработки...',
#   'employer_name': 'КРОК',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84687491',
#   'name': 'Аналитик в отдел отчетности',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Технический склад ума. Опыт в анализе массивов данных (SQL, Excel). Понимание принципов построения отчетности в банке. Важно умение общаться с...',
#   'responsibility': 'Разработка/доработка отчетности (продажи/выполнение KPI) с помощью SQL, Excel. Поддержка региональных пользователей отчетности. Консультация, ответы на запросы. ',
#   'employer_name': 'ХОУМ Банк',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84441501',
#   'name': 'Стажер-Аналитик трендов в AI',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Обучение на 4 курсе бакалавриата или 1-2 курсе магистратуры. - Английский (Upper Intermediate и выше). - Грамотный русский язык. - ',
#   'responsibility': 'В Центр методологии и популяризации Data science Сбера требуется стажер! Наша команда занимается разработкой методологических документов, регламентирующих процесс и стандарты...',
#   'employer_name': 'СБЕР',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84763129',
#   'name': 'Младший аналитик / Социолог (Quantitative Market Research)',
#   'area_name': 'Москва',
#   'salary_from': 50000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее или незаконченное высшее образование по направлению социология, политология или маркетинг, или соответствующий релевантный опыт. Опытный пользователь ПК (Word, Excel...',
#   'responsibility': 'Помощь менеджерам и аналитикам в работе над проектами: Разработка инструментария, разработка анкет. Участие в аналитической части исследовательских проектов. ',
#   'employer_name': 'Profi Online Research',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84667786',
#   'name': 'Младший бизнес-аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Высшее образование. Знание методологий описания бизнес-процессов. Хорошие аналитические навыки. Владение прикладными инструментами моделирования процессов (MS Visio / ARIS / Business Studio).',
#   'responsibility': 'Изучение текущих бизнес-процессов компании и выявление возможностей для их усовершенствования. Интервьюирование держателей бизнес-процессов. Моделирование бизнес-процессов в Business...',
#   'employer_name': 'МОСГАЗ',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84505538',
#   'name': 'Аналитик',
#   'area_name': 'Москва',
#   'salary_from': 0,
#   'salary_to': 0,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Законченное Высшее образование (математическое, экономическое образование как преимущество). Развитое аналитическое мышление, умение работать с большим объемом информации, анализировать полученную информацию...',
#   'responsibility': 'Ключевая задача – Администрирование баз данных. Обязанности: Сбор и консолидация информации о движении товаров компании и остатках по дистрибьюторам и аптечным...',
#   'employer_name': 'BAUSCH HEALTH',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'},
#  {'id': '84296529',
#   'name': 'Аналитик (экономика, информатика, IT)',
#   'area_name': 'Москва',
#   'salary_from': 70000,
#   'salary_to': None,
#   'salary_currency': 'RUR',
#   'salary_gross': False,
#   'requirement': 'Законченное высшее образование. Уверенное знание Excel (сводные таблицы, ВПР и т.д.). Развитое логическое и аналитическое мышление. Высокий уровень грамотности. ',
#   'responsibility': 'Автоматизация аналитических процессов в секторе гос.управления. Приведение к корректному виду большого количества данных. Таблицы, сводная аналитика. Системный анализ. ',
#   'employer_name': 'ГБУ Информационно-Консультационный Центр Департамента Культуры Города Москвы',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта'}]

# %%
import json
import pprint
vac_id = str('83811478')

def getPageVac(vac_id):
    req = requests.get(f'https://api.hh.ru/vacancies/{vac_id}/') # Посылаем запрос к API
    data = req.content.decode() # Декодируем его ответ, чтобы Кириллица отображалась корректно
    req.close()
   
    return data
data_vac = getPageVac((vac_id))
# https://api.hh.ru/vacancies/{vacancy_id}

# %%
data_vac
data_dict = (json.loads(data_vac))
data_dict
# Out:
# {'id': '83811478',
#  'premium': False,
#  'billing_type': {'id': 'standard', 'name': 'Стандарт'},
#  'relations': [],
#  'name': 'Удалённый аналитик по недвижимости (подработка из дома, от 4 часов, без опыта)',
#  'insider_interview': None,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 50000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'allow_messages': True,
#  'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#  'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#  'employment': {'id': 'part', 'name': 'Частичная занятость'},
#  'department': None,
#  'contacts': None,
#  'description': '<p>В связи с расширением требуются начинающие специалисты - аналитики по коммерческой недвижимости на удалённую работу для сбора данных по объектам недвижимости. Работа из дома. Можно без опыта, возможно обучение.</p> <p>ОБЯЗАННОСТИ:<br />- по открытым источникам (Циан, Avito, яндекс.недвижимость и др.) находить объявления по коммерческой недвижимости;<br />- собирать данные по объекту, запрашивать у продавца недостающую информацию;<br />- заполнять таблицы по найденному объекту;<br />- передавать собранные данные менеджеру в установленном формате.</p> <p>ТРЕБОВАНИЯ:<br />- готовность к обучению и усвоению новой информации;<br />- быть на связи и соблюдать сроки;<br />- ответственность, обязательность, внимательность и аккуратность.</p> <p>ПРИ ОТСУТСТВИИ ОПЫТА или знаний, необходимо пройти СТАЖИРОВКУ у нас. В результате у вас появятся следующие компетенции:<br />- понимание рынка коммерческой недвижимости;<br />- умение читать карты и анализировать окружение и местоположение объекта;<br />- умение делать анализ конкуренции и зону охвата;<br />- понимание ликвидности и окупаемости объекта;<br />- умение читать документы по недвижимости и собирать из них информацию.</p> <p>УСЛОВИЯ<br />- возможность приобрести ценый опыт анализа объектов и вырасти профессионально;<br />- реальная практика на настоящих проектах;<br />- работа на подряде, удалённо из дома;<br />- частичная занятость, возможно совмещение;<br />- график свободный. Важно быть на связи в оговоренное время и соблюдать дедлайны;<br />- оплата сдельная процент от сделки (10-30% от суммы, получаемой нанимателем со сделки в зависимости от вашего участия в результате.<br />- для постоянных сотрудников предусмотрен оклад + процент.</p> <p>Требуется амбициозный начинающий специалист с энтузиазмом и желанием работать, расти профессионально и узнавать новое.</p>',
#  'branded_description': None,
#  'vacancy_constructor_template': None,
#  'key_skills': [],
#  'accept_handicapped': False,
#  'accept_kids': False,
#  'archived': False,
#  'response_url': None,
#  'specializations': [],
#  'professional_roles': [{'id': '40', 'name': 'Другое'}],
#  'code': None,
#  'hidden': False,
#  'quick_responses_allowed': False,
#  'driver_license_types': [],
#  'accept_incomplete_resumes': True,
#  'employer': {'id': '5630856',
#   'name': 'Сакулин Игорь Валерьевич',
#   'url': 'https://api.hh.ru/employers/5630856',
#   'alternate_url': 'https://hh.ru/employer/5630856',
#   'logo_urls': None,
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5630856',
#   'accredited_it_employer': False,
#   'trusted': True},
#  'published_at': '2023-07-21T13:28:49+0300',
#  'created_at': '2023-07-21T13:28:49+0300',
#  'initial_created_at': '2023-07-21T13:28:49+0300',
#  'negotiations_url': None,
#  'suitable_resumes_url': None,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=83811478',
#  'has_test': False,
#  'test': None,
#  'alternate_url': 'https://hh.ru/vacancy/83811478',
#  'working_days': [{'id': 'only_saturday_and_sunday',
#    'name': 'Работа только по\xa0сб\xa0и\xa0вс'}],
#  'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#    'name': 'Можно работать сменами по\xa04–6 часов в\xa0день'}],
#  'working_time_modes': [{'id': 'start_after_sixteen',
#    'name': 'Можно начинать работать после 16:00'}],
#  'accept_temporary': False,
#  'languages': []}

# %%
result = []
_id = data_dict.get('id', '')

billing_type = data_dict.get('billing_type', {})
billing_type_id = billing_type.get('id', '')
billing_type_name = billing_type.get('name', '')
experience = data_dict.get('experience', {})
experience_id = experience.get('id', '')
experience_name = experience.get('name', '')
employment = data_dict.get('employment', {})
employment_id = employment.get('id', '')
employment_name = employment.get('name', '')
employer = data_dict.get('employer', {})
employer_id = employer.get('id', '')
employer_name = employer.get('name', '')
employer_url = employer.get('url', '')
working_days = data_dict.get('working_days', [])
working_days_list = ''.join([day.get('name', '') for day in working_days]).replace('\xa0', ' ')
working_time_intervals = data_dict.get('working_time_intervals', [])
working_time_intervals_list = ''.join([interval.get('name', '') for interval in working_time_intervals]).replace('\xa0', ' ')
working_time_modes = data_dict.get('working_time_modes', [])
working_time_modes_list = ''.join([mode.get('name', '') for mode in working_time_modes])
description = data_dict.get('description', '')
area = data_dict.get('area', {})
area_url = area.get('url', '')
salary = data_dict.get('salary', {})
salary_from = salary.get('from', 0)
salary_to = salary.get('to', 0)
salary_currency = salary.get('currency', 'RUR')
type_info = data_dict.get('type', {}) 
type_id = type_info.get('id', '')
type_name = type_info.get('name', '')
key_skills = data_dict.get('key_skills', [])
skills = ''.join([skill for skill in key_skills])
date_pub= data_dict.get("published_at")
date_create = data_dict.get("created_at")
result.append({
    'id': _id,
    'billing_type_id': billing_type_id,
    'billing_type_name': billing_type_name,
    'experience_id': experience_id,
    'experience_name': experience_name,
    'employment_id': employment_id,
    'employment_name': employment_name,
    'employer_id': employer_id,
    'employer_name': employer_name,
    'employer_url': employer_url,
    'working_days': working_days_list,
    'working_time_intervals': working_time_intervals_list,
    'working_time_modes': working_time_modes_list,
    'description': description,
    'area_url': area_url,
    'salary_from': salary_from,
    'salary_to': salary_to,
    'salary_currency': salary_currency,
    'type_id': type_id,
    'type_name': type_name,
    'key_skills': key_skills,
    'date_pub'  : date_pub,
    'date_create':date_create,
})

# %%
result
# Out:
# [{'id': '83811478',
#   'billing_type_id': 'standard',
#   'billing_type_name': 'Стандарт',
#   'experience_id': 'noExperience',
#   'experience_name': 'Нет опыта',
#   'employment_id': 'part',
#   'employment_name': 'Частичная занятость',
#   'employer_id': '5630856',
#   'employer_name': 'Сакулин Игорь Валерьевич',
#   'employer_url': 'https://api.hh.ru/employers/5630856',
#   'working_days': 'Работа только по сб и вс',
#   'working_time_intervals': 'Можно работать сменами по 4–6 часов в день',
#   'working_time_modes': 'Можно начинать работать после 16:00',
#   'description': '<p>В связи с расширением требуются начинающие специалисты - аналитики по коммерческой недвижимости на удалённую работу для сбора данных по объектам недвижимости. Работа из дома. Можно без опыта, возможно обучение.</p> <p>ОБЯЗАННОСТИ:<br />- по открытым источникам (Циан, Avito, яндекс.недвижимость и др.) находить объявления по коммерческой недвижимости;<br />- собирать данные по объекту, запрашивать у продавца недостающую информацию;<br />- заполнять таблицы по найденному объекту;<br />- передавать собранные данные менеджеру в установленном формате.</p> <p>ТРЕБОВАНИЯ:<br />- готовность к обучению и усвоению новой информации;<br />- быть на связи и соблюдать сроки;<br />- ответственность, обязательность, внимательность и аккуратность.</p> <p>ПРИ ОТСУТСТВИИ ОПЫТА или знаний, необходимо пройти СТАЖИРОВКУ у нас. В результате у вас появятся следующие компетенции:<br />- понимание рынка коммерческой недвижимости;<br />- умение читать карты и анализировать окружение и местоположение объекта;<br />- умение делать анализ конкуренции и зону охвата;<br />- понимание ликвидности и окупаемости объекта;<br />- умение читать документы по недвижимости и собирать из них информацию.</p> <p>УСЛОВИЯ<br />- возможность приобрести ценый опыт анализа объектов и вырасти профессионально;<br />- реальная практика на настоящих проектах;<br />- работа на подряде, удалённо из дома;<br />- частичная занятость, возможно совмещение;<br />- график свободный. Важно быть на связи в оговоренное время и соблюдать дедлайны;<br />- оплата сдельная процент от сделки (10-30% от суммы, получаемой нанимателем со сделки в зависимости от вашего участия в результате.<br />- для постоянных сотрудников предусмотрен оклад + процент.</p> <p>Требуется амбициозный начинающий специалист с энтузиазмом и желанием работать, расти профессионально и узнавать новое.</p>',
#   'area_url': 'https://api.hh.ru/areas/1',
#   'salary_from': 50000,
#   'salary_to': 100000,
#   'salary_currency': 'RUR',
#   'type_id': 'open',
#   'type_name': 'Открытая',
#   'key_skills': [],
#   'date_pub': '2023-07-21T13:28:49+0300',
#   'date_create': '2023-07-21T13:28:49+0300'}]

# %%
for page in range(0, 20):
    
    # Преобразуем текст ответа запроса в справочник Python
    jsObj = json.loads(getPage(page))
    
    # Сохраняем файлы в папку {путь до текущего документа со скриптом}\docs\pagination
    # Определяем количество файлов в папке для сохранения документа с ответом запроса
    # Полученное значение используем для формирования имени документа
    nextFileName = './data/raw/pagination/{}.json'.format(len(os.listdir('./data/raw/pagination')))
    
    # Создаем новый документ, записываем в него ответ запроса, после закрываем
    f = open(nextFileName, mode='w', encoding='utf8')
    f.write(json.dumps(jsObj, ensure_ascii=False))
    f.close()
    
    # Проверка на последнюю страницу, если вакансий меньше 2000
    if (jsObj['pages'] - page) <= 1:
        break
    
    # Необязательная задержка, но чтобы не нагружать сервисы hh, оставим. 5 сек мы может подождать
    time.sleep(0.25)
    
print('Старницы поиска собраны')
# Out:
# Старницы поиска собраны

# %%
# Библиотека для анализа данных, представляющая данные в табличном виде называемом DataFrame
# Вся мощь данной библиотеки нам здесь не понадобиться, с ее помощью мы положим
# данные в БД. Можно было бы написать простые insert-ы
import pandas as pd

import json
import os

# Библиотека для работы с СУБД
from sqlalchemy import engine as sql

# Модуль для работы с отображением вывода Jupyter
from IPython import display

# Создаем списки для столбцов таблицы vacancies
IDs = [] # Список идентификаторов вакансий
names = [] # Список наименований вакансий
descriptions = [] # Список описаний вакансий

# Создаем списки для столбцов таблицы skills
skills_vac = [] # Список идентификаторов вакансий
skills_name = [] # Список названий навыков

# В выводе будем отображать прогресс
# Для этого узнаем общее количество файлов, которые надо обработать
# Счетчик обработанных файлов установим в ноль
cnt_docs = len(os.listdir('./docs/vacancies'))
i = 0

# Проходимся по всем файлам в папке vacancies
for fl in os.listdir('./docs/vacancies'):
    
    # Открываем, читаем и закрываем файл
    f = open('./docs/vacancies/{}'.format(fl), encoding='utf8')
    jsonText = f.read()
    f.close()
    
    # Текст файла переводим в справочник
    jsonObj = json.loads(jsonText)
    
    # Заполняем списки для таблиц
    IDs.append(jsonObj['id'])
    names.append(jsonObj['name'])
    descriptions.append(jsonObj['description'])
    
    # Т.к. навыки хранятся в виде массива, то проходимся по нему циклом
    for skl in jsonObj['key_skills']:
        skills_vac.append(jsonObj['id'])
        skills_name.append(skl['name'])
    
    # Увеличиваем счетчик обработанных файлов на 1, очищаем вывод ячейки и выводим прогресс
    i += 1
    display.clear_output(wait=True)
    display.display('Готово {} из {}'.format(i, cnt_docs))


# Создадим соединение с БД
eng = sql.create_engine('postgresql://{Пользователь}:{Пароль}@{Сервер}:{Port}/{База данных}')
conn = eng.connect()

# Создаем пандосовский датафрейм, который затем сохраняем в БД в таблицу vacancies
df = pd.DataFrame({'id': IDs, 'name': names, 'description': descriptions})
df.to_sql('vacancies', conn, schema='public', if_exists='append', index=False)

# Тоже самое, но для таблицы skills
df = pd.DataFrame({'vacancy': skills_vac, 'skill': skills_name})
df.to_sql('skills', conn, schema='public', if_exists='append', index=False)

# Закрываем соединение с БД
conn.close()

# Выводим сообщение об окончании программы
display.clear_output(wait=True)
display.display('Вакансии загружены в БД')

# %%
import pandas as pd
